# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# %% [markdown]
# ## BERTin (BETO)

# %%
# Nombre del modelo en Hugging Face
model_name = "distilbert-base-uncased"

# Descargar y cargar el modelo y el tokenizer
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Tokenizar el input y hacer la inferencia
inputs = tokenizer("Este es un ejemplo", return_tensors="pt")
outputs = model(**inputs)

model_name = "dccuchile/bert-base-spanish-wwm-cased"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## BETO

# %%
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## roBERTuito

# %%
model_name = "mrm8488/robertuito-base-finetuned-spanish-sentiment-analysis"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## XLM-RoBERTa

# %%
model_name = "xlm-roberta-base"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## BERT Multilingual

# %%
model_name = "bert-base-multilingual-cased"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## mBERT-Finetuned

# %%
model_name = "j-hartmann/emotion-english-multilingual-bert"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
