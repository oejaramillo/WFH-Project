# %%
import pandas as pd
import numpy as np
import psycopg2

# %%
host = ""
port = ""
database = ""
user = ""
password = ""

# %%
try:
    conn = psycopg2.connect(
        host=host,
        port=port,
        database=database,
        user=user,
        password=password
    )
    print("Connected to the database successfully!")
except Exception as e:
    print(f"Error connecting to the database: {e}")
# Out:
# Connected to the database successfully!

# %%
query = "SELECT * FROM classification"
datos = pd.read_sql(query, conn)
conn.close()
# Out:
# C:\Users\oscarj\AppData\Local\Temp\ipykernel_15320\734791513.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(query, conn)

# %%
datos = pd.read_csv("datos_app.csv")
len(datos)
# Out:
# 10710

# %%
datos['classification'].value_counts()
# Out:
# classification
# Not WFH    7004
# WFH        3706
# Name: count, dtype: int64

# %% [markdown]
# Leave those ads classified as WFH two times

# %%
duplicated = datos.groupby('ad_id').filter(lambda x: len(x) > 1)

# %%
double_wfh = duplicated.groupby('ad_id').filter(lambda x: (x['classification'] == 'WFH').sum() >= 2)

# %%
wfh_data = double_wfh[~double_wfh.duplicated(subset='ad_id')]

# %%
wfh_data
# Out:
#           id  classifier_id    ad_id classification    ease    workday  \
# 2          3              3  4537889            WFH    easy  not clear
# 3          4              4  4211029            WFH    easy       full
# 4          5              4  4121084            WFH    easy  not clear
# 5          6              4  5084482            WFH    easy  not clear
# 10        11              3  5027173            WFH    easy  not clear
# ...      ...            ...      ...            ...     ...        ...
# 10157  10203             45  4062291            WFH    easy  not clear
# 10163  10210             45  5427844            WFH  medium  not clear
# 10204  10284             43  4323282            WFH    easy       full
# 10226  10183             45  4114638            WFH    easy  not clear
# 10235  10209             45  4059747            WFH    easy  not clear
#
#                         timestamp
# 2      2024-07-14 18:32:31.134518
# 3      2024-07-14 18:39:06.373645
# 4      2024-07-14 18:40:28.214855
# 5       2024-07-14 18:40:54.13361
# 10     2024-07-14 19:07:23.559778
# ...                           ...
# 10157  2024-08-05 22:52:01.449095
# 10163  2024-08-05 22:55:42.234054
# 10204  2024-08-06 18:03:28.030087
# 10226  2024-08-05 22:30:59.149297
# 10235  2024-08-05 22:55:11.328805
#
# [1053 rows x 7 columns]
