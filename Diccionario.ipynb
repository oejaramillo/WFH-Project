# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Chat GPT

# %% [markdown]
# Actúa como un científico de datos y provee una completa lista de palabras clave, frases o n-gramas en español que indiquen que un aviso de trabajo ofrece a sus postulantes la opción de trabajo remoto de maneral parcial o total.

# %%
key_w1 = [
    "Trabajo remoto",
    "Teletrabajo",
    "Modalidad home office",
    "Trabajo a distancia",
    "Opción de trabajar desde casa",
    "Flexibilidad en la ubicación",
    "Horario flexible",
    "Trabajo en línea",
    "Trabajo virtual",
    "Colaboración en línea",
    "Equipo distribuido",
    "Trabajo fuera de la oficina",
    "Laborar desde cualquier lugar",
    "Ubicación geográfica flexible",
    "Trabajo en modalidad remota",
    "Oportunidad para teletrabajar",
    "Modalidad de trabajo flexible",
    "Posibilidad de trabajar de forma remota",
    "Trabajo en modalidad virtual",
    "Oficina virtual",
    "Trabajo desde el hogar",
    "Posibilidad de trabajar a distancia",
    "Modalidad de trabajo a distancia",
    "Horario de trabajo adaptable",
    "Trabajo flexible en ubicación",
    "Equipo remoto",
    "Trabajo en línea desde casa",
    "Oportunidad de teletrabajo parcial",
    "Horario de trabajo remoto",
    "Flexibilidad geográfica"
]

# %% [markdown]
# hazlo otra vez, dame más opciones que pueda utilizar, intenta no repetir

# %%
key_w2 = [
    "Trabajo remoto",
    "Teletrabajo",
    "Modalidad home office",
    "Trabajo a distancia",
    "Opción de trabajar desde casa",
    "Flexibilidad en la ubicación",
    "Horario flexible",
    "Trabajo en línea",
    "Trabajo virtual",
    "Colaboración en línea",
    "Equipo distribuido",
    "Trabajo fuera de la oficina",
    "Laborar desde cualquier lugar",
    "Ubicación geográfica flexible",
    "Trabajo en modalidad remota",
    "Oportunidad para teletrabajar",
    "Modalidad de trabajo flexible",
    "Posibilidad de trabajar de forma remota",
    "Trabajo en modalidad virtual",
    "Oficina virtual",
    "Trabajo desde el hogar",
    "Posibilidad de trabajar a distancia",
    "Modalidad de trabajo a distancia",
    "Horario de trabajo adaptable",
    "Trabajo flexible en ubicación",
    "Equipo remoto",
    "Trabajo en línea desde casa",
    "Oportunidad de teletrabajo parcial",
    "Horario de trabajo remoto",
    "Flexibilidad geográfica",
    "Trabajo sin ubicación fija",
    "Colaboración virtual",
    "Trabajo en equipo remoto",
    "Posibilidad de teletrabajar",
    "Trabajo flexible",
    "Modalidad de trabajo virtual",
    "Trabajo en línea y a distancia",
    "Opción de trabajar de manera virtual",
    "Horario de trabajo flexible",
    "Trabajo desde cualquier ubicación",
    "Posibilidad de laborar remotamente",
    "Equipo disperso geográficamente",
    "Oportunidad de trabajo flexible",
    "Modalidad de teletrabajo",
    "Trabajo a distancia ocasional",
    "Opción de trabajo fuera de la oficina",
    "Trabajo desde tu casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa",
    "Posibilidad de teletrabajar desde el hogar",
    "Trabajo a domicilio",
    "Trabajo en línea desde tu hogar",
    "Horario de trabajo desde casa",
    "Equipo remoto desde casa",
    "Trabajo en modalidad virtual desde tu hogar",
    "Oportunidad de trabajo desde casa",
    "Modalidad de trabajo a distancia desde el hogar",
    "Flexibilidad para trabajar desde casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa y a distancia",
    "Equipo de trabajo remoto desde casa",
    "Posibilidad de teletrabajo desde el hogar",
    "Trabajo flexible desde tu hogar",
    "Modalidad de teletrabajo en casa",
    "Trabajo en línea desde casa",
    "Oportunidad de trabajo virtual desde tu hogar",
    "Horario de trabajo flexible desde casa",
    "Trabajo desde cualquier ubicación, incluido el hogar"
]

# %% [markdown]
# Necesito más

# %%
key_w3 = [
    "Trabajo a domicilio",
    "Trabajo desde cualquier lugar",
    "Opción de teletrabajo",
    "Posibilidad de laborar a distancia",
    "Trabajo en modalidad flexible",
    "Opción de trabajar remotamente",
    "Equipo de trabajo distribuido",
    "Horario laboral adaptable",
    "Trabajo en línea y remoto",
    "Oportunidad de trabajo virtual",
    "Modalidad de trabajo a domicilio",
    "Horario de trabajo a distancia",
    "Posibilidad de colaboración en línea",
    "Trabajo en equipo virtual",
    "Trabajo en modalidad a distancia",
    "Flexibilidad en la ubicación laboral",
    "Trabajo con horario flexible",
    "Opción de laborar desde cualquier lugar",
    "Trabajo fuera de la oficina central",
    "Modalidad de trabajo en línea",
    "Horario adaptable y remoto",
    "Equipo de trabajo geográficamente diverso",
    "Oportunidad de laborar en modalidad virtual",
    "Trabajo con horario a distancia",
    "Posibilidad de trabajo remoto ocasional",
    "Colaboración en línea y a distancia",
    "Trabajo en equipo a distancia",
    "Posibilidad de teletrabajar de manera flexible",
    "Modalidad de trabajo fuera de las instalaciones",
    "Trabajo con opción de home office",
    "Equipo distribuido geográficamente",
    "Oportunidad de colaboración virtual",
    "Trabajo con horario adaptable y a distancia",
    "Modalidad de trabajo desde casa",
    "Trabajo con flexibilidad de ubicación",
    "Colaboración en línea y trabajo a distancia",
    "Equipo de trabajo en modalidad remota",
    "Opción de laborar en línea",
    "Horario laboral flexible y a distancia"
]

# %% [markdown]
# Los anuncios que vamos a analizar son de Chile, intenta considerar esto para ver si puedes ampliar la lista con frases, palabras clave, n-gramas o variaciones de los mismos que indiquen la opción de trabajo desde casa

# %%
key_w4 = [
    "Trabajo remoto",
    "Teletrabajo",
    "Modalidad home office",
    "Trabajo a distancia",
    "Opción de trabajar desde casa",
    "Flexibilidad en la ubicación",
    "Horario flexible",
    "Trabajo en línea",
    "Trabajo virtual",
    "Colaboración en línea",
    "Equipo distribuido",
    "Trabajo fuera de la oficina",
    "Laborar desde cualquier lugar",
    "Ubicación geográfica flexible",
    "Trabajo en modalidad remota",
    "Oportunidad para teletrabajar",
    "Modalidad de trabajo flexible",
    "Posibilidad de trabajar de forma remota",
    "Trabajo en modalidad virtual",
    "Oficina virtual",
    "Trabajo desde el hogar",
    "Posibilidad de trabajar a distancia",
    "Modalidad de trabajo a distancia",
    "Horario de trabajo adaptable",
    "Trabajo flexible en ubicación",
    "Equipo remoto",
    "Trabajo en línea desde casa",
    "Oportunidad de teletrabajo parcial",
    "Horario de trabajo remoto",
    "Flexibilidad geográfica",
    "Trabajo sin ubicación fija",
    "Colaboración virtual",
    "Trabajo en equipo remoto",
    "Posibilidad de teletrabajar",
    "Trabajo flexible",
    "Modalidad de trabajo virtual",
    "Trabajo en línea y a distancia",
    "Opción de trabajar de manera virtual",
    "Horario de trabajo flexible",
    "Trabajo desde cualquier ubicación",
    "Posibilidad de laborar remotamente",
    "Equipo disperso geográficamente",
    "Oportunidad de trabajo flexible",
    "Modalidad de teletrabajo",
    "Trabajo a distancia ocasional",
    "Opción de trabajo fuera de la oficina"
]

# %% [markdown]
# hazlo otra vez, para tener más variaciones posibles, considera sinónimos

# %%
key_w5 = [
    "Trabajo remoto",
    "Teletrabajo",
    "Modalidad home office",
    "Trabajo a distancia",
    "Opción de trabajar desde casa",
    "Flexibilidad en la ubicación",
    "Horario flexible",
    "Trabajo en línea",
    "Trabajo virtual",
    "Colaboración en línea",
    "Equipo distribuido",
    "Trabajo fuera de la oficina",
    "Laborar desde cualquier lugar",
    "Ubicación geográfica flexible",
    "Trabajo en modalidad remota",
    "Oportunidad para teletrabajar",
    "Modalidad de trabajo flexible",
    "Posibilidad de trabajar de forma remota",
    "Trabajo en modalidad virtual",
    "Oficina virtual",
    "Trabajo desde el hogar",
    "Posibilidad de trabajar a distancia",
    "Modalidad de trabajo a distancia",
    "Horario de trabajo adaptable",
    "Trabajo flexible en ubicación",
    "Equipo remoto",
    "Trabajo en línea desde casa",
    "Oportunidad de teletrabajo parcial",
    "Horario de trabajo remoto",
    "Flexibilidad geográfica",
    "Trabajo sin ubicación fija",
    "Colaboración virtual",
    "Trabajo en equipo remoto",
    "Posibilidad de teletrabajar",
    "Trabajo flexible",
    "Modalidad de trabajo virtual",
    "Trabajo en línea y a distancia",
    "Opción de trabajar de manera virtual",
    "Horario de trabajo flexible",
    "Trabajo desde cualquier ubicación",
    "Posibilidad de laborar remotamente",
    "Equipo disperso geográficamente",
    "Oportunidad de trabajo flexible",
    "Modalidad de teletrabajo",
    "Trabajo a distancia ocasional",
    "Opción de trabajo fuera de la oficina",
    "Trabajo desde tu casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa",
    "Posibilidad de teletrabajar desde el hogar",
    "Trabajo a domicilio",
    "Trabajo en línea desde tu hogar",
    "Horario de trabajo desde casa",
    "Equipo remoto desde casa",
    "Trabajo en modalidad virtual desde tu hogar",
    "Oportunidad de trabajo desde casa",
    "Modalidad de trabajo a distancia desde el hogar",
    "Flexibilidad para trabajar desde casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa y a distancia",
    "Equipo de trabajo remoto desde casa",
    "Posibilidad de teletrabajo desde el hogar",
    "Trabajo flexible desde tu hogar",
    "Modalidad de teletrabajo en casa",
    "Trabajo en línea desde casa",
    "Oportunidad de trabajo virtual desde tu hogar",
    "Horario de trabajo flexible desde casa",
    "Trabajo desde cualquier ubicación, incluido el hogar",
    "Empleo remoto",
    "Trabajo virtual desde casa",
    "Flexibilidad para laborar en casa",
    "Modalidad de trabajo a distancia en casa",
    "Equipo a distancia",
    "Posibilidad de trabajar a distancia desde el hogar",
    "Modalidad de teletrabajo desde casa",
    "Trabajo en línea en modalidad remota",
    "Oportunidad de empleo remoto",
    "Horario flexible desde el hogar",
    "Trabajo desde tu hogar de forma remota",
    "Opción de trabajo remoto",
    "Trabajo en modalidad de teletrabajo",
    "Trabajo en modalidad virtual desde casa",
    "Posibilidad de trabajar en línea",
    "Modalidad de trabajo en casa",
    "Horario flexible desde tu hogar",
    "Oportunidad de trabajar en modalidad remota",
    "Trabajo desde tu hogar en modalidad virtual"
]

# %% [markdown]
# finalmente intenta anticipar eufemismos

# %%
key_w6 = [
    "Trabajo remoto",
    "Teletrabajo",
    "Modalidad home office",
    "Trabajo a distancia",
    "Opción de trabajar desde casa",
    "Flexibilidad en la ubicación",
    "Horario flexible",
    "Trabajo en línea",
    "Trabajo virtual",
    "Colaboración en línea",
    "Equipo distribuido",
    "Trabajo fuera de la oficina",
    "Laborar desde cualquier lugar",
    "Ubicación geográfica flexible",
    "Trabajo en modalidad remota",
    "Oportunidad para teletrabajar",
    "Modalidad de trabajo flexible",
    "Posibilidad de trabajar de forma remota",
    "Trabajo en modalidad virtual",
    "Oficina virtual",
    "Trabajo desde el hogar",
    "Posibilidad de trabajar a distancia",
    "Modalidad de trabajo a distancia",
    "Horario de trabajo adaptable",
    "Trabajo flexible en ubicación",
    "Equipo remoto",
    "Trabajo en línea desde casa",
    "Oportunidad de teletrabajo parcial",
    "Horario de trabajo remoto",
    "Flexibilidad geográfica",
    "Trabajo sin ubicación fija",
    "Colaboración virtual",
    "Trabajo en equipo remoto",
    "Posibilidad de teletrabajar",
    "Trabajo flexible",
    "Modalidad de trabajo virtual",
    "Trabajo en línea y a distancia",
    "Opción de trabajar de manera virtual",
    "Horario de trabajo flexible",
    "Trabajo desde cualquier ubicación",
    "Posibilidad de laborar remotamente",
    "Equipo disperso geográficamente",
    "Oportunidad de trabajo flexible",
    "Modalidad de teletrabajo",
    "Trabajo a distancia ocasional",
    "Opción de trabajo fuera de la oficina",
    "Trabajo desde tu casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa",
    "Posibilidad de teletrabajar desde el hogar",
    "Trabajo a domicilio",
    "Trabajo en línea desde tu hogar",
    "Horario de trabajo desde casa",
    "Equipo remoto desde casa",
    "Trabajo en modalidad virtual desde tu hogar",
    "Oportunidad de trabajo desde casa",
    "Modalidad de trabajo a distancia desde el hogar",
    "Flexibilidad para trabajar desde casa",
    "Trabajo en modalidad home office",
    "Trabajo en casa y a distancia",
    "Equipo de trabajo remoto desde casa",
    "Posibilidad de teletrabajo desde el hogar",
    "Trabajo flexible desde tu hogar",
    "Modalidad de teletrabajo en casa",
    "Trabajo en línea desde casa",
    "Oportunidad de trabajo virtual desde tu hogar",
    "Horario de trabajo flexible desde casa",
    "Trabajo desde cualquier ubicación, incluido el hogar",
    "Empleo remoto",
    "Trabajo virtual desde casa",
    "Flexibilidad para laborar en casa",
    "Modalidad de trabajo a distancia en casa",
    "Equipo a distancia",
    "Posibilidad de trabajar a distancia desde el hogar",
    "Modalidad de teletrabajo desde casa",
    "Trabajo en línea en modalidad remota",
    "Oportunidad de empleo remoto",
    "Horario flexible desde el hogar",
    "Trabajo desde tu hogar de forma remota",
    "Opción de trabajo remoto",
    "Trabajo en modalidad de teletrabajo",
    "Trabajo en modalidad virtual desde casa",
    "Posibilidad de trabajar en línea",
    "Modalidad de trabajo en casa",
    "Horario flexible desde tu hogar",
    "Oportunidad de trabajar en modalidad remota",
    "Trabajo desde tu hogar en modalidad virtual",
    "Trabajo con flexibilidad de ubicación",
    "Opción de trabajar fuera de la oficina",
    "Equipo de trabajo en modalidad remota",
    "Trabajo en equipo a distancia",
    "Trabajo en línea y colaboración virtual",
    "Trabajo con horario flexible y remoto",
    "Posibilidad de trabajo a distancia ocasional",
    "Modalidad de trabajo en línea y a distancia",
    "Trabajo flexible y colaborativo",
    "Oportunidad de teletrabajo flexible",
    "Trabajo con opción de horario a distancia",
    "Equipo virtual y trabajo remoto",
    "Trabajo en modalidad a distancia ocasional",
    "Trabajo con horario adaptado y a distancia",
    "Oportunidad de trabajo con flexibilidad geográfica",
    "Modalidad de teletrabajo parcial y remoto",
    "Trabajo flexible con colaboración en línea",
    "Trabajo con opción de ubicación flexible",
    "Oportunidad de trabajo remoto en línea",
    "Trabajo en modalidad flexible y remota",
    "Posibilidad de trabajo en equipo distribuido",
    "Equipo remoto y colaboración virtual",
    "Modalidad de trabajo desde casa con flexibilidad",
    "Trabajo en modalidad virtual y a distancia",
    "Horario de trabajo flexible y remoto",
    "Oportunidad de laborar desde cualquier lugar",
    "Trabajo con flexibilidad en la ubicación",
    "Trabajo en línea y horario de trabajo remoto",
    "Equipo de trabajo geográficamente disperso",
    "Modalidad de teletrabajo y trabajo flexible",
    "Trabajo en casa con colaboración en línea",
    "Trabajo a distancia con horario adaptable",
    "Posibilidad de trabajar en modalidad virtual",
    "Equipo remoto con oportunidad de teletrabajo",
    "Trabajo flexible y oportunidad de teletrabajo",
    "Modalidad de trabajo desde el hogar en línea",
    "Trabajo en modalidad remota y colaboración virtual",
    "Trabajo con flexibilidad horaria y a distancia",
    "Oportunidad de trabajo en modalidad flexible",
    "Trabajo en modalidad virtual y desde el hogar",
    "Equipo en modalidad remota y colaboración en línea",
    "Trabajo con opción de horario adaptable",
    "Posibilidad de laborar en modalidad remota",
    "Trabajo en equipo a distancia y colaboración virtual",
    "Equipo geográficamente distribuido y colaboración en línea",
    "Trabajo flexible con opción de colaboración en línea",
    "Oportunidad de trabajo a distancia y flexible",
    "Modalidad de teletrabajo y colaboración en línea",
    "Trabajo en modalidad flexible y colaborativo",
    "Trabajo desde casa con horario adaptable",
    "Equipo remoto y colaboración en línea",
    "Trabajo en modalidad a distancia y virtual",
    "Posibilidad de trabajar de manera flexible",
    "Equipo de trabajo con opción de ubicación flexible",
    "Modalidad de trabajo remoto y colaboración virtual",
    "Trabajo flexible con colaboración en línea y a distancia",
    "Trabajo en línea y oportunidad de trabajo remoto",
    "Equipo en modalidad virtual y colaboración en línea",
    "Trabajo con flexibilidad de ubicación y horario",
    "Oportunidad de trabajo a distancia y remoto",
    "Modalidad de teletrabajo en línea y colaboración virtual",
    "Trabajo en modalidad flexible y en línea",
    "Trabajo desde casa con oportunidad de trabajo remoto",
    "Equipo geográficamente disperso y colaboración virtual",
    "Trabajo en modalidad remota y oportunidad de teletrabajo",
    "Trabajo con horario adaptable y colaboración en línea",
    "Oportunidad de trabajo flexible y remoto",
    "Modalidad de trabajo a distancia y virtual",
    "Trabajo en modalidad virtual con flexibilidad",
    "Equipo en modalidad remota y a distancia",
    "Trabajo desde casa con horario flexible",
    "Opción de teletrabajo y colaboración en línea",
    "Modalidad de trabajo flexible y desde el hogar",
    "Trabajo en línea con horario flexible",
    "Equipo con opción de trabajo remoto",
    "Trabajo flexible y en línea",
    "Oportunidad de teletrabajo y colaboración virtual",
    "Modalidad de trabajo a distancia y remoto",
    "Trabajo en modalidad remota y virtual",
    "Equipo geográficamente disperso y en línea",
    "Trabajo desde casa con opción de horario flexible",
    "Opción de trabajo flexible y colaboración en línea",
    "Modalidad de teletrabajo y desde el hogar",
    "Trabajo en modalidad flexible y virtual",
    "Equipo en modalidad remota y virtual",
    "Trabajo desde casa con oportunidad de teletrabajo",
    "Horario adaptable y trabajo en línea",
    "Oportunidad de trabajo a distancia y desde el hogar",
    "Modalidad de trabajo en línea y a distancia",
    "Trabajo flexible y colaboración virtual",
    "Equipo con opción de teletrabajo",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Horario flexible y trabajo en línea",
    "Oportunidad de teletrabajo y trabajo en línea",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de horario flexible",
    "Trabajo en modalidad a distancia y virtual",
    "Trabajo desde casa con flexibilidad en el horario",
    "Opción de trabajo en línea y remoto",
    "Modalidad de teletrabajo y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea",
    "Trabajo flexible y en línea",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y virtual",
    "Equipo con opción de trabajo desde casa",
    "Trabajo desde casa y colaboración virtual",
    "Horario adaptable y trabajo en línea",
    "Opción de teletrabajo y desde el hogar",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto",
    "Trabajo en modalidad virtual y en línea",
    "Trabajo desde casa con horario flexible",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo flexible",
    "Trabajo en línea y colaboración en línea",
    "Horario adaptable y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y virtual",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de trabajo a distancia",
    "Trabajo en modalidad a distancia y colaboración virtual",
    "Trabajo desde casa con horario adaptable",
    "Oportunidad de teletrabajo y en modalidad remota",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y colaboración virtual",
    "Equipo con opción de trabajo desde casa",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo en línea",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y en modalidad virtual",
    "Equipo con opción de trabajo en línea y trabajo remoto",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo desde casa",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de trabajo en línea",
    "Oportunidad de teletrabajo y en modalidad remota",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo desde el hogar",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo en modalidad virtual",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde casa",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en línea",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y en modalidad remota",
    "Trabajo desde casa con opción de trabajo en línea",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde casa",
    "Trabajo en modalidad flexible y colaboración en línea",
    "Equipo con opción de trabajo remoto y en línea",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo en modalidad remota",
    "Opción de teletrabajo y en línea",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo desde casa",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y en modalidad virtual",
    "Equipo con opción de trabajo remoto y desde el hogar",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en línea",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo en línea",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo en línea",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo en línea",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto y trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y en línea",
    "Modalidad de trabajo remoto y en línea",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad remota",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad virtual",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad virtual",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo remoto y en modalidad remota",
    "Trabajo en modalidad flexible y desde casa",
    "Equipo con opción de trabajo en línea y en modalidad virtual",
    "Trabajo en línea y en modalidad remota",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad virtual",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario remoto y trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia y desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y desde el hogar",
    "Trabajo en modalidad flexible y en línea",
    "Equipo con opción de trabajo en línea y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario adaptable y trabajo en modalidad remota",
    "Opción de teletrabajo y desde casa",
    "Modalidad de trabajo en línea y en modalidad remota",
    "Trabajo flexible y en modalidad virtual",
    "Equipo con opción de horario flexible y trabajo remoto",
    "Trabajo en modalidad a distancia y en modalidad virtual",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo y desde el hogar",
    "Modalidad de trabajo remoto y en modalidad virtual",
    "Trabajo en modalidad flexible y en modalidad remota",
    "Equipo con opción de trabajo remoto y colaboración en línea",
    "Trabajo en línea y en modalidad virtual",
    "Horario flexible y trabajo desde casa",
    "Opción de teletrabajo y en modalidad remota",
    "Modalidad de trabajo en línea y desde el hogar",
    "Trabajo flexible y en modalidad remota",
    "Equipo con opción de horario remoto and trabajo en modalidad remota",
    "Trabajo en modalidad a distancia y colaboración en línea",
    "Trabajo desde casa con opción de teletrabajo",
    "Oportunidad de teletrabajo and en línea",
    "Modalidad de trabajo remoto and en línea",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad remota",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde el hogar",
    "Modalidad de trabajo remoto and desde el hogar",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde la casa",
    "Modalidad de trabajo remoto and desde la casa",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario flexible and trabajo desde casa",
    "Opción de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo en línea and desde el hogar",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario remoto and trabajo en modalidad virtual",
    "Trabajo en modalidad a distancia and desde el hogar",
    "Trabajo desde casa con opción de trabajo remoto",
    "Oportunidad de teletrabajo and desde la casa",
    "Modalidad de trabajo remoto and desde la casa",
    "Trabajo en modalidad flexible and en línea",
    "Equipo con opción de trabajo en línea and colaboración en línea",
    "Trabajo en línea and en modalidad virtual",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual",
    "Equipo con opción de horario flexible and trabajo remoto",
    "Trabajo en modalidad a distancia and en línea",
    "Trabajo desde casa con opción de trabajo a distancia",
    "Oportunidad de teletrabajo and en modalidad virtual",
    "Modalidad de trabajo remoto and en modalidad remota",
    "Trabajo en modalidad flexible and desde la casa",
    "Equipo con opción de trabajo en línea and en modalidad virtual",
    "Trabajo en línea and en modalidad remota",
    "Horario adaptable and trabajo en modalidad remota",
    "Opción de teletrabajo and desde casa",
    "Modalidad de trabajo en línea and en modalidad remota",
    "Trabajo flexible and en modalidad virtual"
]

# %%
gpt = list(set(key_w1 + key_w2 + key_w3 + key_w4 + key_w5 + key_w6))
gpt = pd.DataFrame(gpt, columns=['key words'])
gpt['origin'] = 'gpt'
len(gpt)
# Out:
# 313

# %% [markdown]
# ## OECD

# %%
oecd = [
    "Home Office",
    "Telearbeit",
    "Heimarbeit",
    "home office",
    "homeoffice",
    "mobiles office",
    "mobiles arbeiten",
    "von zu hause arbeiten",
    "von zuhause arbeiten",
    "arbeiten von zuhause",
    "von zuhause aus",
    "work remotely",
    "work from home",
    "working remotely",
    "working from home",
    "remote work teleworking",
    "remote work",
    "teleworking",
    "telework",
    "telecommute",
    "trabajo a distancia",
    "trabajo remoto",
    "teletrabajo",
    "trabajo desde casa",
    "teletreball",
    "trabajar desde casa",
    "teletrabajar",
    "tele-trabajar",
    "en remoto",
    "télétravail",
    "travail à distance",
    "travail à la maison",
    "de la maison",
    "telelavoro",
    "lavoro a distanza",
    "lavoro in remoto",
    "lavoro da remoto",
    "lavoro da casa",
    "lavorare remotamente",
    "lavorare da remoto",
    "da remoto",
    "smart working",
    "smartworking",
    "テレワーク",
    "在宅ワーク",
    "内職",
    "自宅での勤務",
    "在宅型ワーク",
    "自宅から勤務",
    "thuiswerken",
    "Werken vanuit huis",
    "zdalna",
    "w domu",
    "z domu",
    "telepraca",
    "praca zdalna",
    "trabalho remoto",
    "100% remoto",
    "trabalho de casa",
    "Teletrabalho",
    "Trabalhar remotamente",
    "arbeta på distans",
    "arbeta hemifrån",
    "arbete på distans",
    "arbete hemifrån",
    "distansarbete",
    "Jobb på distans",
    "Distansjobb",
    "Jobba på distans",
    "Jobba hemifrån",
    "Jobb på distans",
    "Jobb hemifrån",
    "Distansjobb",
    "Arbeta på avstånd",
    "Werk van thuis",
    "Remoto",
    "Télétravail",
    "Home Office",
    "Lavoro da casa",
    "Remote",
    "Télétravail",
    "Werk van thuis",
    "En remoto",
    "Home Based",
    "Home Office",
    "Remote",
    "Remote",
    "Remote",
    "Remote",
    "Remote",
    "Remote",
    "Remote",
    "zdalnie",
    "Desde casa",
    "Jobba hemifrån"
]

# %%
oecd = pd.DataFrame(oecd, columns=['key words'])
oecd['origin'] = 'oecd'
len(oecd)
# Out:
# 95

# %% [markdown]
# ## Draca

# %%
draca = ['Home Based', 'Work from Home', 'Home Working', 'Homeworking', 'Home Work', 'Work@Home', 'Remote Working', 'Work Remotely', 'Remote Work', 
         'Location Remote', 'Conducted Remotely', 'Location Fully Remote', 'Position is Remote', 'Telework', 'Teleworking', 'Virtual Job', 'Telecommuting', 'Tele Commuting']

# %%
draca = pd.DataFrame(draca, columns=['key words'])
draca['origin'] = 'draca'
len(draca)
# Out:
# 18

# %%
dic = pd.concat([gpt, oecd, draca], ignore_index=True)
dic = dic.sort_values(by='origin')
dic.drop_duplicates(subset='key words', inplace=True)
len(dic)
# Out:
# 411

# %%
dic['key words2'] = dic['key words'].apply(lambda x: x.title()) #Cada palabra con mayúscula
dic['key words3'] = dic['key words'].apply(lambda x: x.upper()) #Todas en mayúscula
dic['key words4'] = dic['key words'].apply(lambda x: x.lower()) #Todas en minúscula
dic['len'] = dic['key words'].apply(lambda x: len(x.split())) #Número de palabras

# %%
dic.to_excel('dic.xlsx')
